# %%
from analyze_runs import load_sweep_run, plot_multi_mean_std_curves, plot_generalization_heatmaps, plot_multi_spectra, load_sweep_data_from_path, plot_jacobian_singular_vectors
from core.mail import email_pdf

td_config, td_metrics, td_summary = load_sweep_data_from_path("results/fixed/td_exact/mountain_car_sweep/tuning/20260824_212023/MountainCar-v0")
mc_config, mc_metrics, mc_summary = load_sweep_data_from_path("results/fixed/mc_exact/mountain_car_sweep/tuning/20260824_212021/MountainCar-v0")
E_config, E_metrics, E_summary = load_sweep_data_from_path("results/fixed/E_gd_exact/mountain_car_sweep/tuning/20260824_212015/MountainCar-v0")

steps_per_pi = td_config.get("NUM_ENVS", 1) * td_config.get("NUM_STEPS", 1)

# 2. Compare Value Error (nn_weighted_VE) on the same plot with mean & std
fig = plot_multi_mean_std_curves(
    {
        "Exact TD": td_metrics["nn_weighted_VE"],
        "Exact MC": mc_metrics["nn_weighted_VE"],
        "Exact E": E_metrics["nn_weighted_VE"]
    },
    steps_per_pi=steps_per_pi,
    metric_name="Value Error",
    ylabel="MSVE (nn_weighted_VE)",
    log_scale=True, tuning_summaries = {"Expected TD": td_summary, "Supervised Value Learning": mc_summary}
)
# Out:
# Loaded sweep run from results/fixed/td_exact/mountain_car_sweep/tuning/20260824_212023/MountainCar-v0
# Loaded sweep run from results/fixed/mc_exact/mountain_car_sweep/tuning/20260824_212021/MountainCar-v0
# Loaded sweep run from results/fixed/E_gd_exact/mountain_car_sweep/tuning/20260824_212015/MountainCar-v0
# label Exact TD not in tuning summaries
# [Exact TD] Using best combo index 2 from 3D tensor.
# number of seeds: 3
# label Exact MC not in tuning summaries
# [Exact MC] Using best combo index 1 from 3D tensor.
# number of seeds: 3
# label Exact E not in tuning summaries
# [Exact E] Using best combo index 0 from 3D tensor.
# number of seeds: 3

# %%
from analyze_runs import load_sweep_run, plot_multi_mean_std_curves, plot_generalization_heatmaps, plot_multi_spectra, load_sweep_data_from_path, plot_jacobian_singular_vectors
from core.mail import email_pdf

td_config, td_metrics, td_summary = load_sweep_data_from_path("results/fixed/td_exact/mountain_car_sweep/tuning/20260824_212023/MountainCar-v0")
mc_config, mc_metrics, mc_summary = load_sweep_data_from_path("results/fixed/mc_exact/mountain_car_sweep/tuning/20260824_212021/MountainCar-v0")
E_config, E_metrics, E_summary = load_sweep_data_from_path("results/fixed/E_gd_exact/mountain_car_sweep/tuning/20260824_212015/MountainCar-v0")

steps_per_pi = td_config.get("NUM_ENVS", 1) * td_config.get("NUM_STEPS", 1)

# 2. Compare Value Error (nn_weighted_VE) on the same plot with mean & std
fig = plot_multi_mean_std_curves(
    {
        "Exact TD": td_metrics["E"],
        "Exact MC": mc_metrics["E"],
        "Exact E": E_metrics["E"]
    },
    steps_per_pi=steps_per_pi,
    metric_name="Value Error (E)",
    ylabel="E (nn_weighted_VE)",
    log_scale=True, tuning_summaries = {"Expected TD": td_summary, "Supervised Value Learning": mc_summary}
)
# Out:
# Loaded sweep run from results/fixed/td_exact/mountain_car_sweep/tuning/20260824_212023/MountainCar-v0
# Loaded sweep run from results/fixed/mc_exact/mountain_car_sweep/tuning/20260824_212021/MountainCar-v0
# Loaded sweep run from results/fixed/E_gd_exact/mountain_car_sweep/tuning/20260824_212015/MountainCar-v0
# label Exact TD not in tuning summaries
# [Exact TD] Using best combo index 2 from 3D tensor.
# number of seeds: 3
# label Exact MC not in tuning summaries
# [Exact MC] Using best combo index 0 from 3D tensor.
# number of seeds: 3
# label Exact E not in tuning summaries
# [Exact E] Using best combo index 0 from 3D tensor.
# number of seeds: 3

# %%
from analyze_runs import load_sweep_run, plot_multi_mean_std_curves, plot_generalization_heatmaps, plot_multi_spectra, load_sweep_data_from_path, plot_jacobian_singular_vectors
from core.mail import email_pdf

td_config, td_metrics, td_summary = load_sweep_data_from_path("results/fixed/td_exact/tuning/tuning/20260824_212416/FourRooms-misc")
mc_config, mc_metrics, mc_summary = load_sweep_data_from_path("results/fixed/mc_exact/tuning/tuning/20260824_212419/FourRooms-misc")
E_config, E_metrics, E_summary = load_sweep_data_from_path("results/fixed/E_gd_exact/tuning/tuning/20260824_212410/FourRooms-misc")

steps_per_pi = td_config.get("NUM_ENVS", 1) * td_config.get("NUM_STEPS", 1)

# 2. Compare Value Error (nn_weighted_VE) on the same plot with mean & std
fig = plot_multi_mean_std_curves(
    {
        "Exact TD": td_metrics["nn_weighted_VE"],
        "Exact MC": mc_metrics["nn_weighted_VE"],
        "Exact E": E_metrics["nn_weighted_VE"]
    },
    steps_per_pi=steps_per_pi,
    metric_name="Value Error",
    ylabel="MSVE (nn_weighted_VE)",
    log_scale=True, tuning_summaries = {"Expected TD": td_summary, "Supervised Value Learning": mc_summary}
)
# Out:
# Loaded sweep run from results/fixed/td_exact/tuning/tuning/20260824_212416/FourRooms-misc
# Loaded sweep run from results/fixed/mc_exact/tuning/tuning/20260824_212419/FourRooms-misc
# Loaded sweep run from results/fixed/E_gd_exact/tuning/tuning/20260824_212410/FourRooms-misc
# label Exact TD not in tuning summaries
# [Exact TD] Using best combo index 2 from 3D tensor.
# number of seeds: 3
# label Exact MC not in tuning summaries
# [Exact MC] Using best combo index 1 from 3D tensor.
# number of seeds: 3
# label Exact E not in tuning summaries
# [Exact E] Using best combo index 1 from 3D tensor.
# number of seeds: 3
